# %%
import chromadb
client = chromadb.Client()

# %%
collection = client.create_collection("news_articles")

# %%
collection.add(
    ids = ["id1","id2","id3","id4"],
    documents = [
        "Apple is leading in a smart phone game with iphone sales up by 35%",
        "Tesla booked a minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin c and various antioxidants",
        "SpaceX got NASA contract worth 10 billions $",
    ]
)
# Out:
# C:\Users\Sogo\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:03<00:00, 27.7MiB/s]

# %%
data = collection.get(
    include = ["documents", "embeddings", "metadatas"]
)

for i,emb in enumerate (data["embeddings"]):
    print(f"\nDocument {i+1}")
    print("Text:", data["documents"][i])
    print("Embedding length:", len(emb))
    print("First 10 values:", emb[:10])
# Out:
# Document 1
# Text: Apple is leading in a smart phone game with iphone sales up by 35%
# Embedding length: 384
# First 10 values: [ 0.0364045   0.01021044  0.08642431 -0.12735225 -0.01895931  0.00309626
#   0.01671754  0.05566163  0.0237683   0.11325452]
#
# Document 2
# Text: Tesla booked a minor profit of 1 billion $ in Q2
# Embedding length: 384
# First 10 values: [ 0.032283    0.08888532  0.02695832  0.07444271 -0.0677371  -0.0352956
#  -0.02407439  0.10166305  0.02283022  0.02386419]
#
# Document 3
# Text: Apples are high in fiber, vitamin c and various antioxidants
# Embedding length: 384
# First 10 values: [ 0.04282142 -0.02908741  0.01251423  0.08055453  0.00226207  0.02243376
#  -0.00943858 -0.01025317  0.00157955  0.0185274 ]
#
# Document 4
# Text: SpaceX got NASA contract worth 10 billions $
# Embedding length: 384
# First 10 values: [-0.02116845  0.03544135  0.05499415 -0.02739447 -0.07838549 -0.0406099
#   0.06312121  0.05320035  0.02528723  0.07318715]

# %%
results = collection.query(
    query_texts = ["This is a query related to Elon Musk"],
    n_results = 2
)
print(results)
# Out:
# {'ids': [['id2', 'id4']], 'embeddings': None, 'documents': [['Tesla booked a minor profit of 1 billion $ in Q2', 'SpaceX got NASA contract worth 10 billions $']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.5166926383972168, 1.5436153411865234]]}
