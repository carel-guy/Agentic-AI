# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")

response = llm.invoke("How many moons does Jupiter have?")
print(response.text)
# Out:
# As of the most recent data from the International Astronomical Union and NASA, Jupiter has **95 officially recognized moons**.
#
# However, this number frequently changes as astronomers discover new, smaller moons using more powerful telescopes.
#
# The moons are generally divided into two groups:
# 1. **The Galilean Moons:** The four largest and most famous moons—**Io, Europa, Ganymede, and Callisto**—which were discovered by Galileo Galilei in 1610.
# 2. **The Smaller Moons:** The remaining 91 moons are much smaller and are often "irregular," meaning they have eccentric orbits and were likely asteroids captured by Jupiter's massive gravity.

# %%
response = llm.invoke([
    ["system","You are a helpful assistant that answers in short one line"],
    ["human", "How many moons does Jupiter have?"]
])
print(response.text)
# Out:
# Jupiter has 95 moons.

# %%
prompt = "Write a single tagline for a quirky coffee shop, Only output the tagline, nothing else."
llm = ChatGoogleGenerativeAI(model = "gemini-3.6-flash", temperature = 0)
response = llm.invoke(prompt)
print(response.text)
# Out:
# C:\Users\Sogo\Documents\agentic-ai\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Serious coffee for wonderfully weird people.

# %%
#CALL LLM USING GROQ MODELS#

# %%
from langchain_groq import ChatGroq

# %%
llm =  ChatGroq (model="openai/gpt-oss-120b", reasoning_format="parsed")
messages = [
    (
  "system","You are a helpful assistant that answers in short one line"  
),
    (
        "human","How many moons does jupiter have?"
    )
]
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Jupiter has 95 known moons.
